# %%
#Instalando a biblioteca openpyxl para leitura de arquivos Excel
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\esb11\appdata\local\programs\python\python314\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\esb11\appdata\local\programs\python\python314\lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importando bibliotecas
import pandas as pd

# Variavel para apontar o arquivo original
file_path = '../data/raw/BASE DE DADOS PEDE 2024 - DATATHON.xlsx'

# Ler o arquivo e apontar as abas que existem
xls = pd.ExcelFile(file_path)

nomes_das_abas = xls.sheet_names

print(nomes_das_abas)
# Out:
# ['PEDE2022', 'PEDE2023', 'PEDE2024']

# %%
# Carregando as abas em dataframes separados
df_2022 = pd.read_excel(file_path, sheet_name='PEDE2022')
df_2023 = pd.read_excel(file_path, sheet_name='PEDE2023')
df_2024 = pd.read_excel(file_path, sheet_name='PEDE2024')

# Exibindo tamano de linhas e colunas de cada dataframe
print(f"PEDE2022: {df_2022.shape}")
print(f"PEDE2023: {df_2023.shape}")
print(f"PEDE2024: {df_2024.shape}")

# Exibindo nome das colunas de cada dataframe
print(f"\nColunas PEDE2022: {df_2022.columns.tolist()}")
print(f"Colunas PEDE2023: {df_2023.columns.tolist()}")
print(f"Colunas PEDE2024: {df_2024.columns.tolist()}")

# Exibindo informações gerais dos dataframes
print("\nInformações PEDE2022:")
print(df_2022.info())
print("\nInformações PEDE2023:")
print(df_2023.info())
print("\nInformações PEDE2024:")
print(df_2024.info())
# Out:
# PEDE2022: (860, 42)
# PEDE2023: (1014, 48)
# PEDE2024: (1156, 50)
#
# Colunas PEDE2022: ['RA', 'Fase', 'Turma', 'Nome', 'Ano nasc', 'Idade 22', 'Gênero', 'Ano ingresso', 'Instituição de ensino', 'Pedra 20', 'Pedra 21', 'Pedra 22', 'INDE 22', 'Cg', 'Cf', 'Ct', 'Nº Av', 'Avaliador1', 'Rec Av1', 'Avaliador2', 'Rec Av2', 'Avaliador3', 'Rec Av3', 'Avaliador4', 'Rec Av4', 'IAA', 'IEG', 'IPS', 'Rec Psicologia', 'IDA', 'Matem', 'Portug', 'Inglês', 'Indicado', 'Atingiu PV', 'IPV', 'IAN', 'Fase ideal', 'Defas', 'Destaque IEG', 'Destaque IDA', 'Destaque IPV']
# Colunas PEDE2023: ['RA', 'Fase', 'INDE 2023', 'Pedra 2023', 'Turma', 'Nome Anonimizado', 'Data de Nasc', 'Idade', 'Gênero', 'Ano ingresso', 'Instituição de ensino', 'Pedra 20', 'Pedra 21', 'Pedra 22', 'Pedra 23', 'INDE 22', 'INDE 23', 'Cg', 'Cf', 'Ct', 'Nº Av', 'Avaliador1', 'Rec Av1', 'Avaliador2', 'Rec Av2', 'Avaliador3', 'Rec Av3', 'Avaliador4', 'Rec Av4', 'IAA', 'IEG', 'IPS', 'IPP', 'Rec Psicologia', 'IDA', 'Mat', 'Por', 'Ing', 'Indicado', 'Atingiu PV', 'IPV', 'IAN', 'Fase Ideal', 'Defasagem', 'Destaque IEG', 'Destaque IDA', 'Destaque IPV', 'Destaque IPV.1']
# Colunas PEDE2024: ['RA', 'Fase', 'INDE 2024', 'Pedra 2024', 'Turma', 'Nome Anonimizado', 'Data de Nasc', 'Idade', 'Gênero', 'Ano ingresso', 'Instituição de ensino', 'Pedra 20', 'Pedra 21', 'Pedra 22', 'Pedra 23', 'INDE 22', 'INDE 23', 'Cg', 'Cf', 'Ct', 'Nº Av', 'Avaliador1', 'Rec Av1', 'Avaliador2', 'Rec Av2', 'Avaliador3', 'Avaliador4', 'Avaliador5', 'Avaliador6', 'IAA', 'IEG', 'IPS', 'IPP', 'Rec Psicologia', 'IDA', 'Mat', 'Por', 'Ing', 'Indicado', 'Atingiu PV', 'IPV', 'IAN', 'Fase Ideal', 'Defasagem', 'Destaque IEG', 'Destaque IDA', 'Destaque IPV', 'Escola', 'Ativo/ Inativo', 'Ativo/ Inativo.1']
#
# Informações PEDE2022:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860 entries, 0 to 859
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RA                     860 non-null    object
#  1   Fase                   860 non-null    int64
#  2   Turma                  860 non-null    object
#  3   Nome                   860 non-null    object
#  4   Ano nasc               860 non-null    int64
#  5   Idade 22               860 non-null    int64
#  6   Gênero                 860 non-null    object
#  7   Ano ingresso           860 non-null    int64
#  8   Instituição de ensino  860 non-null    object
#  9   Pedra 20               323 non-null    object
#  10  Pedra 21               462 non-null    object
#  11  Pedra 22               860 non-null    object
#  12  INDE 22                860 non-null    float64
#  13  Cg                     860 non-null    int64
#  14  Cf                     860 non-null    int64
#  15  Ct                     860 non-null    int64
#  16  Nº Av                  860 non-null    int64
#  17  Avaliador1             860 non-null    object
#  18  Rec Av1                860 non-null    object
#  19  Avaliador2             860 non-null    object
#  20  Rec Av2                860 non-null    object
#  21  Avaliador3             534 non-null    object
#  22  Rec Av3                860 non-null    object
#  23  Avaliador4             310 non-null    object
#  24  Rec Av4                296 non-null    object
#  25  IAA                    860 non-null    float64
#  26  IEG                    860 non-null    float64
#  27  IPS                    860 non-null    float64
#  28  Rec Psicologia         860 non-null    object
#  29  IDA                    860 non-null    float64
#  30  Matem                  858 non-null    float64
#  31  Portug                 858 non-null    float64
#  32  Inglês                 283 non-null    float64
#  33  Indicado               860 non-null    object
#  34  Atingiu PV             860 non-null    object
#  35  IPV                    860 non-null    float64
#  36  IAN                    860 non-null    float64
#  37  Fase ideal             860 non-null    object
#  38  Defas                  860 non-null    int64
#  39  Destaque IEG           860 non-null    object
#  40  Destaque IDA           860 non-null    object
#  41  Destaque IPV           860 non-null    object
# dtypes: float64(10), int64(9), object(23)
# memory usage: 282.3+ KB
# None
#
# Informações PEDE2023:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RA                     1014 non-null   object
#  1   Fase                   1014 non-null   object
#  2   INDE 2023              931 non-null    float64
#  3   Pedra 2023             931 non-null    object
#  4   Turma                  1014 non-null   object
#  5   Nome Anonimizado       1014 non-null   object
#  6   Data de Nasc           1014 non-null   object
#  7   Idade                  1014 non-null   object
#  8   Gênero                 1014 non-null   object
#  9   Ano ingresso           1014 non-null   int64
#  10  Instituição de ensino  1014 non-null   object
#  11  Pedra 20               240 non-null    object
#  12  Pedra 21               335 non-null    object
#  13  Pedra 22               600 non-null    object
#  14  Pedra 23               0 non-null      float64
#  15  INDE 22                600 non-null    float64
#  16  INDE 23                0 non-null      float64
#  17  Cg                     0 non-null      float64
#  18  Cf                     0 non-null      float64
#  19  Ct                     0 non-null      float64
#  20  Nº Av                  938 non-null    float64
#  21  Avaliador1             938 non-null    object
#  22  Rec Av1                0 non-null      float64
#  23  Avaliador2             938 non-null    object
#  24  Rec Av2                0 non-null      float64
#  25  Avaliador3             707 non-null    object
#  26  Rec Av3                0 non-null      float64
#  27  Avaliador4             334 non-null    object
#  28  Rec Av4                0 non-null      float64
#  29  IAA                    951 non-null    float64
#  30  IEG                    938 non-null    float64
#  31  IPS                    945 non-null    float64
#  32  IPP                    938 non-null    float64
#  33  Rec Psicologia         0 non-null      float64
#  34  IDA                    937 non-null    float64
#  35  Mat                    937 non-null    float64
#  36  Por                    937 non-null    float64
#  37  Ing                    334 non-null    float64
#  38  Indicado               0 non-null      float64
#  39  Atingiu PV             0 non-null      float64
#  40  IPV                    938 non-null    float64
#  41  IAN                    1014 non-null   float64
#  42  Fase Ideal             1014 non-null   object
#  43  Defasagem              1014 non-null   int64
#  44  Destaque IEG           0 non-null      float64
#  45  Destaque IDA           0 non-null      float64
#  46  Destaque IPV           0 non-null      float64
#  47  Destaque IPV.1         0 non-null      float64
# dtypes: float64(29), int64(2), object(17)
# memory usage: 380.4+ KB
# None
#
# Informações PEDE2024:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 50 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RA                     1156 non-null   object
#  1   Fase                   1156 non-null   object
#  2   INDE 2024              1092 non-null   object
#  3   Pedra 2024             1092 non-null   object
#  4   Turma                  1156 non-null   object
#  5   Nome Anonimizado       1156 non-null   object
#  6   Data de Nasc           1156 non-null   datetime64[ns]
#  7   Idade                  1156 non-null   int64
#  8   Gênero                 1156 non-null   object
#  9   Ano ingresso           1156 non-null   int64
#  10  Instituição de ensino  1155 non-null   object
#  11  Pedra 20               191 non-null    object
#  12  Pedra 21               264 non-null    object
#  13  Pedra 22               472 non-null    object
#  14  Pedra 23               690 non-null    object
#  15  INDE 22                472 non-null    float64
#  16  INDE 23                690 non-null    float64
#  17  Cg                     0 non-null      float64
#  18  Cf                     0 non-null      float64
#  19  Ct                     0 non-null      float64
#  20  Nº Av                  1156 non-null   int64
#  21  Avaliador1             1029 non-null   object
#  22  Rec Av1                0 non-null      float64
#  23  Avaliador2             1029 non-null   object
#  24  Rec Av2                0 non-null      float64
#  25  Avaliador3             793 non-null    object
#  26  Avaliador4             407 non-null    object
#  27  Avaliador5             148 non-null    object
#  28  Avaliador6             6 non-null      object
#  29  IAA                    1054 non-null   float64
#  30  IEG                    1156 non-null   float64
#  31  IPS                    1054 non-null   float64
#  32  IPP                    1054 non-null   float64
#  33  Rec Psicologia         0 non-null      float64
#  34  IDA                    1055 non-null   float64
#  35  Mat                    1051 non-null   float64
#  36  Por                    1050 non-null   float64
#  37  Ing                    474 non-null    float64
#  38  Indicado               0 non-null      float64
#  39  Atingiu PV             0 non-null      float64
#  40  IPV                    1054 non-null   float64
#  41  IAN                    1156 non-null   float64
#  42  Fase Ideal             1156 non-null   object
#  43  Defasagem              1156 non-null   int64
#  44  Destaque IEG           0 non-null      float64
#  45  Destaque IDA           0 non-null      float64
#  46  Destaque IPV           0 non-null      float64
#  47  Escola                 1155 non-null   object
#  48  Ativo/ Inativo         1156 non-null   object
#  49  Ativo/ Inativo.1       1156 non-null   object
# dtypes: datetime64[ns](1), float64(23), int64(4), object(22)
# memory usage: 451.7+ KB
# None

# %%
# Renomeando colunas para padronização
df_2022.rename(
    columns={
        'Nome': 'Nome Anonimizado',
        'Idade 22': 'Idade',
        'Matem': 'Mat',
        'Portug': 'Por',
        'Inglês': 'Ing',
        'Defas': 'Defasagem',
        'INDE 22': 'INDE',
        'Pedra 22': 'Pedra',
        'Fase ideal': 'Fase Ideal'
    },
    inplace=True
)

df_2023.rename(
    columns={
        'INDE 2023': 'INDE',
        'Pedra 2023': 'Pedra'
    },
    inplace=True
)

df_2024.rename(
    columns={
        'INDE 2024': 'INDE',
        'Pedra 2024': 'Pedra'
    },
    inplace=True
)

# Removendo colunas desnecessárias ou sem dados
df_2022.drop(
    columns=['Cg', 'Cf', 'Ct', 'Rec Av1', 'Rec Av2', 'Rec Av3', 'Rec Av4', 'Destaque IEG', 'Destaque IDA', 'Destaque IPV', 'Indicado', 'Atingiu PV', 'Rec Psicologia', 'Avaliador1', 'Avaliador2', 'Avaliador3', 'Avaliador4', 'Pedra 20', 'Pedra 21'],
    inplace=True
)

df_2023.drop(
    columns=['Cg', 'Cf', 'Ct', 'Rec Av1', 'Rec Av2', 'Rec Av3', 'Rec Av4', 'Destaque IEG', 'Destaque IDA', 'Destaque IPV', 'Destaque IPV.1', 'Indicado', 'Atingiu PV', 'Rec Psicologia', 'Avaliador1', 'Avaliador2', 'Avaliador3', 'Avaliador4', 'Pedra 20', 'Pedra 21', 'Pedra 22', 'Pedra 23', 'INDE 22', 'INDE 23'],
    inplace=True
)

df_2024.drop(
    columns=['Cg', 'Cf', 'Ct', 'Rec Av1', 'Rec Av2', 'Destaque IEG', 'Destaque IDA', 'Destaque IPV', 'Indicado', 'Atingiu PV', 'Rec Psicologia', 'Avaliador1', 'Avaliador2', 'Avaliador3', 'Avaliador4', 'Avaliador5', 'Avaliador6', 'Pedra 20', 'Pedra 21', 'Pedra 22', 'Pedra 23', 'Ativo/ Inativo.1', 'INDE 22', 'INDE 23'],
    inplace=True
)

# Adicionando coluna de ano para cada dataframe
df_2022['Ano'] = 2022
df_2023['Ano'] = 2023
df_2024['Ano'] = 2024

# Concatenando os dataframes em um único dataframe
df_historico = pd.concat([df_2022, df_2023, df_2024], ignore_index=True)

df_historico.shape
# Out:
# (3030, 28)

# %%
df_historico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3030 entries, 0 to 3029
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RA                     3030 non-null   object
#  1   Fase                   3030 non-null   object
#  2   Turma                  3030 non-null   object
#  3   Nome Anonimizado       3030 non-null   object
#  4   Ano nasc               860 non-null    float64
#  5   Idade                  3030 non-null   object
#  6   Gênero                 3030 non-null   object
#  7   Ano ingresso           3030 non-null   int64
#  8   Instituição de ensino  3029 non-null   object
#  9   Pedra                  2883 non-null   object
#  10  INDE                   2883 non-null   object
#  11  Nº Av                  2954 non-null   float64
#  12  IAA                    2865 non-null   float64
#  13  IEG                    2954 non-null   float64
#  14  IPS                    2859 non-null   float64
#  15  IDA                    2852 non-null   float64
#  16  Mat                    2846 non-null   float64
#  17  Por                    2845 non-null   float64
#  18  Ing                    1091 non-null   float64
#  19  IPV                    2852 non-null   float64
#  20  IAN                    3030 non-null   float64
#  21  Fase Ideal             3030 non-null   object
#  22  Defasagem              3030 non-null   int64
#  23  Ano                    3030 non-null   int64
#  24  Data de Nasc           2170 non-null   object
#  25  IPP                    1992 non-null   float64
#  26  Escola                 1155 non-null   object
#  27  Ativo/ Inativo         1156 non-null   object
# dtypes: float64(12), int64(3), object(13)
# memory usage: 662.9+ KB

# %%
# Limpando texto da coluna INDE e convertendo para numérico
df_historico['INDE'] = pd.to_numeric(df_historico['INDE'], errors='coerce')

# Imprimindo os valores unicos da coluna pedra e contando a frequencia de cada valor
print(df_historico['Pedra'].unique())
# Out:
# ['Quartzo' 'Ametista' 'Ágata' 'Topázio' 'Agata' nan 'INCLUIR']

# %%
# substituindo valor da pedra "Incluir" por vazio
df_historico['Pedra'] = df_historico['Pedra'].replace('INCLUIR', pd.NA)

# %%
df_historico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3030 entries, 0 to 3029
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RA                     3030 non-null   object
#  1   Fase                   3030 non-null   object
#  2   Turma                  3030 non-null   object
#  3   Nome Anonimizado       3030 non-null   object
#  4   Ano nasc               860 non-null    float64
#  5   Idade                  3030 non-null   object
#  6   Gênero                 3030 non-null   object
#  7   Ano ingresso           3030 non-null   int64
#  8   Instituição de ensino  3029 non-null   object
#  9   Pedra                  2845 non-null   object
#  10  INDE                   2845 non-null   float64
#  11  Nº Av                  2954 non-null   float64
#  12  IAA                    2865 non-null   float64
#  13  IEG                    2954 non-null   float64
#  14  IPS                    2859 non-null   float64
#  15  IDA                    2852 non-null   float64
#  16  Mat                    2846 non-null   float64
#  17  Por                    2845 non-null   float64
#  18  Ing                    1091 non-null   float64
#  19  IPV                    2852 non-null   float64
#  20  IAN                    3030 non-null   float64
#  21  Fase Ideal             3030 non-null   object
#  22  Defasagem              3030 non-null   int64
#  23  Ano                    3030 non-null   int64
#  24  Data de Nasc           2170 non-null   object
#  25  IPP                    1992 non-null   float64
#  26  Escola                 1155 non-null   object
#  27  Ativo/ Inativo         1156 non-null   object
# dtypes: float64(13), int64(3), object(12)
# memory usage: 662.9+ KB

# %%
# Tratando a coluna de idade
# pegar somente as linhas que contem '1900'
mask_erro = df_historico['Idade'].astype(str).str.contains('1900')

# transformando o erro em data e extraindo somente o dia
df_historico.loc[mask_erro, 'Idade'] = pd.to_datetime(df_historico.loc[mask_erro, 'Idade']).dt.day

# convertendo a coluna de idade para numérico
df_historico['Idade'] = pd.to_numeric(df_historico['Idade'], errors='coerce')

# %%
df_historico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3030 entries, 0 to 3029
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RA                     3030 non-null   object
#  1   Fase                   3030 non-null   object
#  2   Turma                  3030 non-null   object
#  3   Nome Anonimizado       3030 non-null   object
#  4   Ano nasc               860 non-null    float64
#  5   Idade                  3030 non-null   int64
#  6   Gênero                 3030 non-null   object
#  7   Ano ingresso           3030 non-null   int64
#  8   Instituição de ensino  3029 non-null   object
#  9   Pedra                  2845 non-null   object
#  10  INDE                   2845 non-null   float64
#  11  Nº Av                  2954 non-null   float64
#  12  IAA                    2865 non-null   float64
#  13  IEG                    2954 non-null   float64
#  14  IPS                    2859 non-null   float64
#  15  IDA                    2852 non-null   float64
#  16  Mat                    2846 non-null   float64
#  17  Por                    2845 non-null   float64
#  18  Ing                    1091 non-null   float64
#  19  IPV                    2852 non-null   float64
#  20  IAN                    3030 non-null   float64
#  21  Fase Ideal             3030 non-null   object
#  22  Defasagem              3030 non-null   int64
#  23  Ano                    3030 non-null   int64
#  24  Data de Nasc           2170 non-null   object
#  25  IPP                    1992 non-null   float64
#  26  Escola                 1155 non-null   object
#  27  Ativo/ Inativo         1156 non-null   object
# dtypes: float64(13), int64(4), object(11)
# memory usage: 662.9+ KB

# %%
df_historico.loc[df_historico['RA'] == 'RA-864', 'Idade'].astype(str)
# Out:
# 863    8
# Name: Idade, dtype: object

# %%
df_historico.describe()
# Out:
#           Ano nasc        Idade  Ano ingresso         INDE        Nº Av  \
# count   860.000000  3030.000000   3030.000000  2845.000000  2954.000000
# mean   2009.861628    12.527063   2021.563696     7.269915     3.031821
# std       2.771998     3.299273      1.822171     0.991767     1.063670
# min    2001.000000     7.000000   2016.000000     3.032000     0.000000
# 25%    2008.000000    10.000000   2021.000000     6.675200     2.000000
# 50%    2010.000000    12.000000   2022.000000     7.388267     3.000000
# 75%    2012.000000    15.000000   2023.000000     7.986867     4.000000
# max    2015.000000    27.000000   2024.000000     9.531325     6.000000
#
#                IAA          IEG          IPS          IDA          Mat  \
# count  2865.000000  2954.000000  2859.000000  2852.000000  2846.000000
# mean      7.918225     7.945696     6.287129     6.375964     6.161595
# std       2.626209     2.152281     1.792491     1.956637     2.398341
# min       0.000000     0.000000     2.500000     0.000000     0.000000
# 25%       7.900000     7.300000     5.020000     5.100000     4.800000
# 50%       8.751000     8.600000     7.500000     6.666667     6.300000
# 75%       9.500000     9.400000     7.510000     7.833333     8.000000
# max      10.002000    10.000000    10.000000    10.000000    10.000000
#
#                Por          Ing          IPV          IAN    Defasagem  \
# count  2845.000000  1091.000000  2852.000000  3030.000000  3030.000000
# mean      6.430668     6.289413     7.545476     7.179043    -0.642904
# std       2.138916     2.732636     1.084347     2.535266     0.866382
# min       0.000000     0.000000     2.500000     2.500000    -5.000000
# 25%       5.200000     4.500000     6.984000     5.000000    -1.000000
# 50%       6.700000     6.700000     7.583000     5.000000    -1.000000
# 75%       8.000000     8.500000     8.255000    10.000000     0.000000
# max      10.000000    10.000000    10.010000    10.000000     3.000000
#
#               Ano          IPP
# count  3030.00000  1992.000000
# mean   2023.09769     7.555203
# std       0.80995     0.938990
# min    2022.00000     2.500000
# 25%    2022.00000     7.083333
# 50%    2023.00000     7.500000
# 75%    2024.00000     8.125000
# max    2024.00000    10.000000
